# %%
from json import loads
from collections import Counter
import matplotlib.pyplot as plt

# %%
POST_PATH = "Comment_Analysis.json"

# %%
polarity = []
lang = []
with open(POST_PATH, 'r') as post_file:
    for line in post_file:
        post = loads(line)
        if post["sentiment"] == {}:
            polarity.append('NA')
        elif post["sentiment"] == 'ERR':
            polarity.append('NA')
        else:
            polarity.append(post["sentiment"])
        lang.append(post["lang"])

# %% [markdown]
# # Nº de P, N, NEU

# %%
for i in polarity:
    if type(i) is not str:
        print(i)
        print(type(i))

# %%
PolCounter = Counter(polarity)
for pol, count in PolCounter.items():
    print(f"{pol}: {count}")
# Out:
# Neutral: 6206
# Negative: 10384
# Positive: 6610
# NA: 7

# %%
print(set(polarity))
# Out:
# {'Positive', 'NA', 'Negative', 'Neutral'}

# %% [markdown]
# # PIECHART con %

# %%
labels = PolCounter.keys() 
counts = PolCounter.values()
colors = ['lightcoral', 'lightgreen', 'cornflowerblue', 'plum']
labels = ["Negative", "Neutral", "Positive", "NA"]
# Create the pie chart
plt.figure(figsize=(11.5, 8))
plt.pie(counts, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("Polarity distributions",fontsize=18)
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.legend(labels, title="Polarity", loc="upper left",fontsize=16)# bbox_to_anchor=(1, 0, 0.5, 1))

# Display the pie chart
plt.show()

# %% [markdown]
# # Lang stats

# %%
lang
# Out:
# ['pt',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'ca',
#  'pt',
#  'es',
#  'es',
#  'es',
#  'es',
#  'pt',
#  'None',
#  'pt',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'ca',
#  'pt',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'hr',
#  'es',
#  'es',
#  'None',
#  'lv',
#  'es',
#  'es',
#  'es',
#  'es',
#  'pt',
#  'pt',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'en',
#  'es',
#  'en',
#  'es',
#  'en',
#  'es',
#  'en',
#  'es',
#  'en',
#  'es',
#  'es',
#  'en',
#  'es',
#  'en',
#  'en',
#  'en',
#  'en',
#  'es',
#  'es',
#  'es',
#  'es',
#  'en',
#  'es',
#  'en',
#  'es',
#  'de',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'es',
#  'en',
#  'en',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'en',
#  'es',
#  'en',
#  'es',
#  'es',
#  'es',
#  'en',
#  'es',
#  'es',
#  'en',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'es',
#  'en',
#  'en',
#  'fr',
#  'pt',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'en',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'it',
#  'es',
#  'None',
#  'en',
#  'None',
#  'es',
#  'es',
#  'pt',
#  'None',
#  'hr',
#  'es',
#  'es',
#  'None',
#  'es',
#  'it',
#  'None',
#  'None',
#  'es',
#  'None',
#  'es',
#  'ca',
#  'ca',
#  'es',
#  'pt',
#  'es',
#  'None',
#  'es',
#  'de',
#  'es',
#  'es',
#  'es',
#  'fr',
#  'en',
#  'fr',
#  'es',
#  'pt',
#  'es',
#  'es',
#  'pt',
#  'ca',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'pt',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'ca',
#  'pt',
#  'es',
#  'es',
#  'es',
#  'es',
#  'hr',
#  'hr',
#  'es',
#  'es',
#  'None',
#  'lv',
#  'es',
#  'es',
#  'es',
#  'es',
#  'pt',
#  'pt',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'en',
#  'es',
#  'es',
#  'None',
#  'None',
#  'pt',
#  'so',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'pt',
#  'sl',
#  'es',
#  'None',
#  'pl',
#  'None',
#  'es',
#  'None',
#  'es',
#  'hu',
#  'es',
#  'None',
#  'fi',
#  'hr',
#  'id',
#  'es',
#  'es',
#  'None',
#  'None',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'en',
#  'fr',
#  'en',
#  'None',
#  'en',
#  'None',
#  'lt',
#  'es',
#  'es',
#  'es',
#  'en',
#  'en',
#  'en',
#  'es',
#  'vi',
#  'None',
#  'it',
#  'lt',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'en',
#  'en',
#  'en',
#  'es',
#  'es',
#  'es',
#  'es',
#  'en',
#  'es',
#  'es',
#  'it',
#  'es',
#  'es',
#  'es',
#  'tl',
#  'None',
#  'es',
#  'es',
#  'es',
#  'it',
#  'es',
#  'es',
#  'ro',
#  'de',
#  'es',
#  'es',
#  'en',
#  'so',
#  'None',
#  'no',
#  'es',
#  'es',
#  'it',
#  'it',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'it',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'pt',
#  'es',
#  'es',
#  'pt',
#  'id',
#  'None',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'it',
#  'None',
#  'es',
#  'es',
#  'None',
#  'es',
#  'en',
#  'es',
#  'pt',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'fi',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'None',
#  'None',
#  'es',
#  'None',
#  'es',
#  'es',
#  'it',
#  'pt',
#  'pt',
#  'tl',
#  'es',
#  'es',
#  'None',
#  'ro',
#  'es',
#  'es',
#  'it',
#  'es',
#  'es',
#  'es',
#  'es',
#  'ca',
#  'es',
#  'None',
#  'es',
#  'fr',
#  'None',
#  'None',
#  'pt',
#  'es',
#  'None',
#  'es',
#  'es',
#  'en',
#  'hr',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'pt',
#  'es',
#  'pt',
#  'None',
#  'None',
#  'tr',
#  'it',
#  'pt',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'nl',
#  'es',
#  'es',
#  'ro',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'it',
#  'None',
#  'None',
#  'None',
#  'hu',
#  'None',
#  'es',
#  'es',
#  'lt',
#  'es',
#  'cy',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'None',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'en',
#  'None',
#  'es',
#  'es',
#  'hu',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'ro',
#  'sk',
#  'None',
#  'es',
#  'None',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'pt',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'None',
#  'es',
#  'es',
#  'es',
#  'en',
#  'es',
#  'es',
#  'es',
#  'lt',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'None',
#  'None',
#  'en',
#  'fr',
#  'es',
#  'it',
#  'es',
#  'es',
#  'ro',
#  'pt',
#  'lt',
#  'es',
#  'es',
#  'None',
#  'None',
#  'None',
#  'de',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'sw',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'None',
#  'None',
#  'es',
#  'es',
#  'None',
#  'None',
#  'None',
#  'es',
#  'None',
#  'es',
#  'ca',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'None',
#  'None',
#  'es',
#  'es',
#  'es',
#  'en',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'ca',
#  'en',
#  'es',
#  'es',
#  'en',
#  'es',
#  'None',
#  'en',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'None',
#  'es',
#  'None',
#  'ro',
#  'None',
#  'None',
#  'None',
#  'None',
#  'None',
#  'es',
#  'None',
#  'it',
#  'es',
#  'es',
#  'it',
#  'None',
#  'None',
#  'es',
#  'None',
#  'it',
#  'es',
#  'None',
#  'None',
#  'None',
#  'es',
#  'it',
#  'es',
#  'None',
#  'None',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'sw',
#  'es',
#  'es',
#  'None',
#  'None',
#  'en',
#  'None',
#  'es',
#  'es',
#  'None',
#  'en',
#  'de',
#  'pt',
#  'ca',
#  'de',
#  'en',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'None',
#  'no',
#  'None',
#  'None',
#  'lv',
#  'None',
#  'af',
#  'es',
#  'pt',
#  'None',
#  'en',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'en',
#  'None',
#  'es',
#  'es',
#  'pt',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'it',
#  'es',
#  'nl',
#  'it',
#  'es',
#  'fr',
#  'None',
#  'es',
#  'None',
#  'None',
#  'pt',
#  'es',
#  'None',
#  'es',
#  'None',
#  'es',
#  'es',
#  'None',
#  'it',
#  'es',
#  'es',
#  'es',
#  'af',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'et',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'ca',
#  'es',
#  'es',
#  'es',
#  'fr',
#  'es',
#  'ca',
#  'es',
#  'hu',
#  'es',
#  'nl',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'et',
#  'es',
#  'en',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'None',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'id',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'tl',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'ro',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'en',
#  'es',
#  'es',
#  'es',
#  'tl',
#  'ca',
#  'cs',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'en',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'ro',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'et',
#  'es',
#  'et',
#  'None',
#  'ca',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'ca',
#  'es',
#  'es',
#  'es',
#  'None',
#  'None',
#  'es',
#  'es',
#  'es',
#  'it',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'sl',
#  'es',
#  'es',
#  'pt',
#  'None',
#  'es',
#  'es',
#  'None',
#  'vi',
#  'None',
#  'None',
#  'es',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'es',
#  'None',
#  'es',
#  'es',
#  'None',
#  'sk',
#  'es',
#  'es',
#  'es',
#  'es',
#  'pt',
#  'None',
#  'es',
#  'es',
#  'es',
#  'pt',
#  'sk',
#  'pt',
#  ...]

# %%
lang = list(map(lambda x: x.replace('sl', 'es'), lang))
lang = list(map(lambda x: x.replace('tl', 'es'), lang))
lang = list(map(lambda x: x.replace('lv', 'es'), lang))
lang = list(map(lambda x: x.replace('', 'none'), lang))

# %%
print(f"Languages: {set(lang)}")
langCounter = Counter(lang)
for idiom, count in langCounter.items():
    print(f"{idiom}: {count}")
# Out:
# Languages: {'nonecnonesnone', 'noneNnoneononennoneenone', 'noneenonennone', 'nonefnonernone', 'nonesnoneqnone', 'noneenonesnone', 'nonepnonelnone', 'nonesnonewnone', 'noneznonehnone-nonecnonennone', 'nonernoneonone', 'nonesnoneknone', 'nonesnonevnone', 'nonehnonernone', 'noneinonetnone', 'nonecnoneynone', 'noneenonetnone', 'nonepnonetnone', 'noneinonednone', 'nonesnoneonone', 'nonetnonernone', 'nonelnonetnone', 'nonecnoneanone', 'nonednoneenone', 'noneenonelnone', 'nonevnoneinone', 'nonennoneonone', 'nonennonelnone', 'noneanonefnone', 'nonefnoneinone', 'noneunoneknone', 'nonednoneanone', 'nonehnoneunone'}
# nonepnonetnone: 874
# noneenonesnone: 15425
# noneNnoneononennoneenone: 3112
# nonecnoneanone: 345
# nonehnonernone: 60
# noneenonennone: 888
# nonednoneenone: 146
# nonefnonernone: 170
# noneinonetnone: 587
# nonesnoneonone: 147
# nonepnonelnone: 22
# nonehnoneunone: 283
# nonefnoneinone: 79
# noneinonednone: 143
# nonelnonetnone: 102
# nonevnoneinone: 19
# nonernoneonone: 153
# nonennoneonone: 32
# nonetnonernone: 35
# nonennonelnone: 187
# nonecnoneynone: 57
# nonesnoneknone: 40
# nonesnonewnone: 45
# noneanonefnone: 90
# noneenonetnone: 93
# nonecnonesnone: 14
# nonednoneanone: 22
# nonesnoneqnone: 21
# nonesnonevnone: 13
# noneenonelnone: 1
# noneunoneknone: 1
# noneznonehnone-nonecnonennone: 1

# %%
labels = ['Spanish', 'Italian', 'Portuguese', 'English', 'None']

# %%
#labels = langCounter.keys()
counts = langCounter.values()

# Create the pie chart
plt.figure(figsize=(8, 6))
plt.pie(counts, autopct='%1.1f%%', startangle=140, pctdistance=1.05)
plt.title("Language distributions")
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.legend(labels, title="", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

# Display the pie chart
plt.show()
