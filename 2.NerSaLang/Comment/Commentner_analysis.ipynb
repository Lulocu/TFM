# %%
from json import loads
from collections import Counter
import matplotlib.pyplot as plt

# %%
POST_PATH = "Comment_Analysis.json"

# %%
ner = []
per = []
org = []
misc = []
loc = []
with open(POST_PATH, 'r') as post_file:
    for line in post_file:
        post = loads(line)

        for l in post["ner"].keys():
            if l == "PER":
                ner = ner + post["ner"][l]
                per = per + post["ner"][l]
            elif l == "ORG":
                ner = ner + post["ner"][l]
                org = org + post["ner"][l]
            elif l == "MISC":
                ner = ner + post["ner"][l]
                misc = misc + post["ner"][l]
            elif l == "LOC":
                ner = ner + post["ner"][l]
                loc = loc + post["ner"][l]
            else:
                print(l)

# %% [markdown]
# # Ner

# %%
print(len(set(ner)))
print(len(set(per)))
print(len(set(org)))
print(len(set(misc)))
print(len(set(loc)))
# Out:
# 7464
# 1803
# 1019
# 3666
# 1255

# %%
print(len(ner))
print(len(per))
print(len(org))
print(len(misc))
print(len(loc))
# Out:
# 16924
# 3860
# 1982
# 8305
# 2777

# %%
ner_count = Counter(ner)
per_count = Counter(per)
org_count = Counter(org)
misc_count = Counter(misc)
loc_count = Counter(loc)

# %%
for pol, count in ner_count.most_common(10):
    print(f"{pol}: {count}")
# Out:
# Dios: 749
# ❤️: 380
# ️: 348
# Jesús: 123
# Amén: 111
# Argentina: 101
# Chile: 88
# Lucio: 86
# ❤️❤️❤️: 82
# 💚: 78

# %%
for pol, count in per_count.most_common(10):
    print(f"{pol}: {count}")
# Out:
# Jesús: 123
# Lucio: 86
# Cristo: 70
# Amén: 62
# Señor: 56
# Bueno: 45
# Send: 37
# 🤷: 35
# Asco: 32
# Jajajaja: 31

# %%
for pol, count in org_count.most_common(10):
    print(f"{pol}: {count}")
# Out:
# 💔: 57
# 🤦: 50
# DIOS: 47
# NO: 36
# 👌: 26
# ABORTO: 25
# OMS: 21
# ONU: 20
# NoAlAborto: 20
# ✨: 18

# %%
for pol, count in misc_count.most_common(11):
    print(f"{pol}: {count}")
# Out:
# Dios: 749
# ❤️: 380
# ️: 347
# ❤️❤️❤️: 82
# 💚: 78
# 🏼: 66
# @youngesthuman: 66
# @shopipi_3062: 65
# ❤️❤️: 63
# ️🤦🏻‍: 59
# ️🤦: 46

# %%
for pol, count in loc_count.most_common(10):
    print(f"{pol}: {count}")
# Out:
# Argentina: 101
# Chile: 88
# Amén: 49
# Precio: 49
# 😮: 44
# chile: 40
# Provida: 36
# NO: 29
# Amen: 28
# 🤮: 26

# %% [markdown]
# # PIECHARTs con %

# %%
ner_count.keys()
# Out:
# dict_keys(['PATRIARCADO', 'Navarra', 'Feliz Navidad!', '️', 'Feliz Navidad', 'vaya', 'Muy Feliz Navidad!!!!', 'Gracias Espíritu Santo', 'Nuestra Santísima', 'Gracias Niño Dios', 'Gracias Señor Dios', 'Dios', 'Gracias San José', 'Nazareth', '💉', 'giulan barre', 'miocarditIs', 'trombosis', '💔', 'Sanito', 'COVID', 'Las consequências', '🤷🏻\u200d', '.....', 'Yes', 'Felicitaciones', '🇦', 'IG', 'UNIVERSIDAD DE CHILE', '3NF3RM0', 'CORRUPCIÓN', '🤦', 'U de Chile', 'DSMV', 'DSMV-TR', 'Asociación de Psiquiatría', 'Orientacion', 'p3d0f1l0s', 'INSTITUCION', 'ENFERMA', 'Universidad', 'Chile 2022', 'Yaaay', 'Chile', 'Cristian', 'UNA', '😡', 'Repudio', '🤮🤮', 'N F E R M O N I V E L S A Y A Y I N', 'Vomitar', 'https://drive.google.com/file/d/1FCoklsomXEuM5Ezbo6ozBB9rAPZhUoKE/view?usp=drivesdk', 'Repulsivo!!!', 'Horrible!!!', 'Satanico', '🤮', '🤦🤦🤦🤦', 'Juan Gómez Millas', 'Suena', 'Potencialidades', 'M', 'Horrible!!', 'Niño', 'Tesis', 'Maldit4s lacras 🤮', 'Favor', '🤦🏻\u200d', '️🤦🏻\u200d', '@uchile', 'del.2020', 'Cristo', 'Anticristo', 'Señor', 'Santísima Virgen María', 'sodoma', 'Camino Neocatecumenal', 'Opus Dei', 'España', 'Diego', 'Gracias a Dios', 'SCJN', 'CJF', '@arturozaldivarl Gracias a Dios', '🇽🇲🇽 No', 'YA', 'PINTASTE', 'ROJO MUERTE', 'Basado', 'Papá Noel', 'Jesús', 'Seguro', 'María', 'Jesus❤', 'Chuck Norris', 'Cristiana', 'Jajaja', '❤️', 'Ri Sim', 'Jajajajaja', 'Jajajaja P3nd3j0s', 'DESEADOS', '🥰 ❤️', 'El”“', 'Sodoma', 'Jsjsjajsjsjsjsjs', 'JAJAJAJAJJAJAJ', 'copa! Campeones', '❤️🔥', 'Adolf Hitler', 'Herodes', 'Aldolfs Hitlers', 'Padre Nuestro', 'Juez', 'Dios Todopoderoso', 'en España', 'Progres', 'Anda', '💚', '😌', 'trump #', 'seraley #', 'Praise God', '❤️❤️❤️', 'CORRUPTO', 'NI IZQUIERDA', 'NI DERECHA', 'HA SIDO.LP.MAS TORCIDO', 'Truw', '👎', 'HOMBRES', 'NO SOMOS', 'ORGULLO', 'DESENCIA', 'Acaso', 'FEMIMARXISMO', 'Envíalo', 'Si', 'Católico', 'Mexicanos', 'Nitofilia', 'Inhumano', 'Asco', 'Macaya', 'CHILENOS', 'BIEN', 'MACAYA  PERDIO', 'SUS COMENTARIOS NO TIENEN NINGUN VALOR PARA LOS', 'Presidente', 'José Antonio Kast', 'mmm', 'Mía Isabella', '💚💚💚💚💚💚💚💚💚', 'Sabes', 'GESTANTES', 'JAJAJAJAJAJAJAJA', 'Wow! Increíble', 'Cuba', 'sepan', 'CAZZATA', 'JAJAJAJAJAJAJAJAJ', 'Cerra', 'Provida', 'Kjjj', 'Necesitamos', 'ecuador', 'Bueno', 'Kast', 'Boric', 'Confirmo!!!', 'Fanáticos', '💚 América', 'Dragon Ball', 'Pepe', 'Exacto', 'Viva la Virgen', 'IZQUIERDA', 'CENTRO ETC', 'CORRUPTOS', 'TODOS', 'Castro', 'Ortega', 'Maduro', 'Putin', 'Perú', 'Rusia', 'Kshksjsksjsjsjjsjsjsjjsjs', '❤️❤️', '\U0001faf6', '❤️❤️❤️❤️❤️❤️', 'DM @mexico_community_', 'Asi', 'Teoria', 'Raul', 'Madre María Santísima de San Juan', '🕊️', 'Amen', 'El Lagarto', '🔥😂1a Linea', 'BESTIAS', 'TERF-antifeminista', 'KFC', 'Lula', '👌', 'MUY', 'Bienvenidos', '️😎', '✌️😎', '🧍🏻\u200d', 'Chileno', 'Quién', 'EXISTE', 'Ahhh', 'Amor de Dios Santo', 'rusia', '️\u200d🌈🚫', 'SEND PIC ON', 'JAJAJJAJAJAJAJJA PAYASOS', 'SUS FIESTAS PRIVADAS', 'Ahora', 'Talento', 'Exacto 👌', 'corrupta', 'Justicia', 'Perdon?como', 'Preciosa', 'Perdón', 'Genio!!!', 'Nuestro Señor', 'Evangelio', 'México', 'Crack 🔥🔥', '🕊💫', 'Genio', '♥️', '🇦🇷🇦🇷🇦🇷🇦', 'Ya desapareció a los delicuentes extranjeros', 'Europa', 'perdona', 'Vuestra', 'Eutanasia', 'Nigeria', 'África', 'Asia', '@herqles.es', 'Kiiiuu', '🤷🏼\u200d♀️', 'Valiente', '❤️❤️❤️❤️', 'Diosito', 'Belén', 'Hipócritass', 'Trauma', 'Violento', 'Al revés?', 'Pinochet', 'Argentina', '@unidosxlavida', 'Gabriel', 'Javier', 'Rivadavia', 'Alberto', 'Vidas', 'Digo', 'mendoza', 'Si A La Vida💙✊🏾', '🧬', 'ProVida', '🔥🔥🔥', '❤️\u200d🔥🔥❤️\u200d🔥', 'Espiritu de Dios 🔥', 'MATERNIDAD SERA DESEADA O', 'NO SERÁ', 'ayudan', '\U0001f979🙁', 'Bogotá', '💯', 'NFT', '♥', '♥}Hello you', 'Agradecida', '@_realityrecords', 'LO', 'OTROS', 'VIOLENCIA', 'VEN', 'NO SUFREN', 'CONCILIAR EN.LOS.DIFERENCIAS', 'PARTIDOS POLÍTICOS', 'PARTIDOS DIVIDEN', 'SIEMBRAN.ODIO', 'PUEBLO', 'PASAN.LA PAGINA', 'PRIVADAS...DESPIERTEN', 'NO CAIGAN.EN.EL.JUEGO ESTÚPIDO QUE.NO DEJA.NADA', 'Faltó Evo Morales', 'DISCURSO', 'PRETENDER', 'DESCONOCER', 'SI  ...

# %%
labels = ["Persons", "Miscellany", "Locations", "Oganizations"]#ner_count.keys()
counts = [len(per), len(misc), len(loc), len(org)]#ner_count.values()
colors = ['lightcoral', 'lightgreen', 'cornflowerblue', 'plum'] 

# Create the pie chart
plt.figure(figsize=(13, 8))
plt.pie(counts, autopct='%1.1f%%', startangle=140, colors=colors)
plt.title("Distribution of named entity categories",fontsize=18)
plt.axis('equal')  # Equal aspect ratio ensures the pie chart is circular.
plt.legend(labels, title="Polarity", loc="upper left",fontsize=16)
# Display the pie chart
plt.show()
