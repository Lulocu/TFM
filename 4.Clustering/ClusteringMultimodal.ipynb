# %%
# !pip install umap-learn
# Out:
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.10.1)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.56.4)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))': /simple/pynndescent/
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 30.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn) (67.7.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)
# Building wheels for collected packages: umap-learn, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82807 sha256=8f78c33ac07baa7930b47ce9f84c254b0c6fbad460e50c038acb4f18ad3858dc
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55615 sha256=2e337426474d1a55da0389643d46f13e74f482486f72c0167986729f1c390487
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built umap-learn pynndescent
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.10 umap-learn-0.5.3

# %%
# !pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 71.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# Successfully installed scikit-learn-1.3.0

# %%
from sklearn.cluster import HDBSCAN

# %%
from sklearn.cluster import DBSCAN, OPTICS

import pandas as pd
from google.colab import drive
import umap
import matplotlib.pyplot as plt
from sklearn.metrics import davies_bouldin_score, calinski_harabasz_score, silhouette_score

# %%
drive.mount('/content/drive')

#input_path="/content/drive/MyDrive/TFM/Instagram.Post.json"
EMB_PATHS="/content/drive/MyDrive/TFM/Embeddings/ImgEmbeddings/ALIGNEmbeddings.csv"

data = pd.read_csv(EMB_PATHS, header=None)
ids = data.iloc[:, 0]
features = data.iloc[:, 1:]
# Out:
# Mounted at /content/drive

# %%
def generate_clusters(message_embeddings,
                    n_neighbors,
                    n_components,
                    min_cluster_size,
                    random_state = None):
  """
  Generate HDBSCAN cluster object after reducing embedding dimensionality with UMAP
  """

  umap_embeddings = (umap.UMAP(n_neighbors=n_neighbors,
                              n_components=n_components,
                              metric='cosine',
                              random_state=random_state)
                          .fit_transform(message_embeddings))

  clusters = DBSCAN(min_samples = min_cluster_size,
                              metric='euclidean').fit_predict(umap_embeddings)

  return clusters

# %%
def evaluate_clustering(title, features, labels):
    """
    Calculate clustering evaluation metrics for a given clustering result and print the results.

    Parameters:
    - title: A string, title for the clustering result.
    - features: Features used for clustering (numpy array or DataFrame).
    - labels: Cluster labels assigned by the clustering algorithm.
    """
    try:
      davies_bouldin = davies_bouldin_score(features, labels)
    except:
      davies_bouldin = 'Not applicable'

    try:
      calinski_harabasz = calinski_harabasz_score(features, labels)
    except:
      calinski_harabasz = 'Not applicable'

    try:
      silhouette = silhouette_score(features, labels)
    except:
      silhouette = 'Not applicable'
    try:
      n_clusters = len(set(labels))
    except:
      n_clusters = 'Not applicable'

    print(f"{title} Clustering Evaluation:")
    print(f"Davies-Bouldin Score: {davies_bouldin}")
    print(f"Calinski-Harabasz Score: {calinski_harabasz}")
    print(f"Silhouette Score: {silhouette}\n")
    print(f"Number of clusters: {n_clusters}\n")

# %%
for n_neighbors in (5, 50, 100):
  for n_components in (3, 5, 20 , 50, features.shape[1]):
    for min_cluster_size in (50, 100, 500, 1000):
      cluster_labels = generate_clusters(features,
          n_neighbors, n_components, min_cluster_size)
      evaluate_clustering(f"DBSCAN-{n_neighbors}_{n_components}_{min_cluster_size}", features, cluster_labels)
# Out:
# DBSCAN-5_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.3413759345777003
# Calinski-Harabasz Score: 110.82239598596574
# Silhouette Score: -0.009187537918944744
#
# Number of clusters: 17
#
# DBSCAN-5_3_100 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_3_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.383102546491725
# Calinski-Harabasz Score: 91.44273274727043
# Silhouette Score: -0.02669555757595669
#
# Number of clusters: 23
#
# DBSCAN-5_5_100 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_5_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.614711579963434
# Calinski-Harabasz Score: 91.77893135967135
# Silhouette Score: -0.007833858022133733
#
# Number of clusters: 18
#
# DBSCAN-5_20_100 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_20_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.349624699854562
# Calinski-Harabasz Score: 90.84678239638629
# Silhouette Score: -0.05796922360673075
#
# Number of clusters: 22
#
# DBSCAN-5_50_100 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_50_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_1279_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.429508768704015
# Calinski-Harabasz Score: 98.95674200078523
# Silhouette Score: 0.0075963187841086525
#
# Number of clusters: 22
#
# DBSCAN-5_1279_100 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_1279_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_1279_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-50_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.0957857157353885
# Calinski-Harabasz Score: 238.1856950744767
# Silhouette Score: 0.2338602838496633
#
# Number of clusters: 19
#
# DBSCAN-50_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.1775233857706993
# Calinski-Harabasz Score: 360.81115701438614
# Silhouette Score: 0.17670840409291044
#
# Number of clusters: 10
#
# DBSCAN-50_3_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-50_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-50_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.1705983631512726
# Calinski-Harabasz Score: 243.87698146074524
# Silhouette Score: 0.24440218985687073
#
# Number of clusters: 21
#
# DBSCAN-50_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.161494399370251
# Calinski-Harabasz Score: 341.61362398126465
# Silhouette Score: 0.1557555558551514
#
# Number of clusters: 10
#
# DBSCAN-50_5_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-50_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-50_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.1587804369906562
# Calinski-Harabasz Score: 236.05553879074296
# Silhouette Score: 0.2403942458007623
#
# Number of clusters: 21
#
# DBSCAN-50_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.1589002567336055
# Calinski-Harabasz Score: 343.55259543710116
# Silhouette Score: 0.15810457183449192
#
# Number of clusters: 10
#
# DBSCAN-50_20_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-50_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-50_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.1634253578284675
# Calinski-Harabasz Score: 229.75429712380736
# Silhouette Score: 0.22978494361513765
#
# Number of clusters: 21
#
# DBSCAN-50_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.13968817920133
# Calinski-Harabasz Score: 294.531814285582
# Silhouette Score: 0.09011497943627049
#
# Number of clusters: 10
#
# DBSCAN-50_50_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-50_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-50_1279_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.1742562641767273
# Calinski-Harabasz Score: 225.8131850312035
# Silhouette Score: 0.24791125702317968
#
# Number of clusters: 22
#
# DBSCAN-50_1279_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.1730442339673033
# Calinski-Harabasz Score: 352.98470497212054
# Silhouette Score: 0.15164765463687654
#
# Number of clusters: 9
#
# DBSCAN-50_1279_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-50_1279_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-100_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.070187503584363
# Calinski-Harabasz Score: 234.82472160857574
# Silhouette Score: 0.2418403297052312
#
# Number of clusters: 20
#
# DBSCAN-100_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.210784991225286
# Calinski-Harabasz Score: 327.50642627197965
# Silhouette Score: 0.17926599860597126
#
# Number of clusters: 12
#
# DBSCAN-100_3_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9930978443684396
# Calinski-Harabasz Score: 542.6021218166007
# Silhouette Score: 0.06188279365253348
#
# Number of clusters: 2
#
# DBSCAN-100_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-100_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.0470861097358375
# Calinski-Harabasz Score: 236.37888137759475
# Silhouette Score: 0.24353423824671588
#
# Number of clusters: 20
#
# DBSCAN-100_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.1582118688220047
# Calinski-Harabasz Score: 346.8445065098674
# Silhouette Score: 0.18038939064979373
#
# Number of clusters: 11
#
# DBSCAN-100_5_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-100_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-100_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.097660698318129
# Calinski-Harabasz Score: 232.39293707173027
# Silhouette Score: 0.24178673221007835
#
# Number of clusters: 20
#
# DBSCAN-100_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.2219369670112825
# Calinski-Harabasz Score: 326.971845656496
# Silhouette Score: 0.18138832533799878
#
# Number of clusters: 12
#
# DBSCAN-100_20_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-100_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-100_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.103950105671109
# Calinski-Harabasz Score: 252.17786647706697
# Silhouette Score: 0.2510231336808283
#
# Number of clusters: 20
#
# DBSCAN-100_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.201029855090983
# Calinski-Harabasz Score: 336.27120265220725
# Silhouette Score: 0.17546458799829254
#
# Number of clusters: 11
#
# DBSCAN-100_50_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-100_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-100_1279_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.1351067820175538
# Calinski-Harabasz Score: 241.18358511718617
# Silhouette Score: 0.25310097453349073
#
# Number of clusters: 21
#
# DBSCAN-100_1279_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.1737563034743217
# Calinski-Harabasz Score: 364.0926205318897
# Silhouette Score: 0.1785223791702472
#
# Number of clusters: 10
#
# DBSCAN-100_1279_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-100_1279_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1

# %%
def generate_clusters(message_embeddings,
                    n_neighbors,
                    n_components,
                    min_cluster_size,
                    random_state = None):
  """
  Generate HDBSCAN cluster object after reducing embedding dimensionality with UMAP
  """

  umap_embeddings = (umap.UMAP(n_neighbors=n_neighbors,
                              n_components=n_components,
                              metric='cosine',
                              random_state=random_state)
                          .fit_transform(message_embeddings))

  clusters = OPTICS(min_samples = min_cluster_size
                        ).fit_predict(umap_embeddings)

  return clusters

# %%
for n_neighbors in (5, 50, 100):
  for n_components in (3, 5, 20 , 50, features.shape[1]):
    for min_cluster_size in (50, 100, 500, 1000):
      cluster_labels = generate_clusters(features,
          n_neighbors, n_components, min_cluster_size)
      evaluate_clustering(f"OPTICS-{n_neighbors}_{n_components}_{min_cluster_size}", features, cluster_labels)
# Out:
# OPTICS-5_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.175997091816757
# Calinski-Harabasz Score: 65.54262765445979
# Silhouette Score: -0.20296661497850177
#
# Number of clusters: 26
#
# OPTICS-5_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.0748404843754535
# Calinski-Harabasz Score: 266.9445819840568
# Silhouette Score: 0.06596542550531417
#
# Number of clusters: 8
#
# OPTICS-5_3_500 Clustering Evaluation:
# Davies-Bouldin Score: 2.0048066805904092
# Calinski-Harabasz Score: 567.2751865884095
# Silhouette Score: 0.08908564679529661
#
# Number of clusters: 3
#
# OPTICS-5_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# OPTICS-5_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.21077697068013
# Calinski-Harabasz Score: 105.29670276597236
# Silhouette Score: -0.19501856220114758
#
# Number of clusters: 25
#
# OPTICS-5_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.080841051576759
# Calinski-Harabasz Score: 266.0765657851359
# Silhouette Score: 0.11977060181032646
#
# Number of clusters: 9
#
# OPTICS-5_5_500 Clustering Evaluation:
# Davies-Bouldin Score: 2.444557182627008
# Calinski-Harabasz Score: 685.6275246769824
# Silhouette Score: 0.1324786793285656
#
# Number of clusters: 3
#
# OPTICS-5_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: 2.547734461384024
# Calinski-Harabasz Score: 799.9298273671798
# Silhouette Score: 0.14179548503192704
#
# Number of clusters: 2
#
# OPTICS-5_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.3164292686056203
# Calinski-Harabasz Score: 129.5839261511964
# Silhouette Score: -0.12047465884912528
#
# Number of clusters: 26
#
# OPTICS-5_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.9498346843515524
# Calinski-Harabasz Score: 193.11588155233093
# Silhouette Score: -0.008851453061532788
#
# Number of clusters: 8
#
# OPTICS-5_20_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.96159080351978
# Calinski-Harabasz Score: 663.0774080705389
# Silhouette Score: 0.13509614800818073
#
# Number of clusters: 3
#
# OPTICS-5_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: 2.6548916631073016
# Calinski-Harabasz Score: 807.1791577248872
# Silhouette Score: 0.1366725646338303
#
# Number of clusters: 2
#
# OPTICS-5_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.5776574787264557
# Calinski-Harabasz Score: 130.16534814999557
# Silhouette Score: 0.0721624880504244
#
# Number of clusters: 22
#
# OPTICS-5_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.1362370561104287
# Calinski-Harabasz Score: 284.42420242495444
# Silhouette Score: 0.1298641330595603
#
# Number of clusters: 10
#
# OPTICS-5_50_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.9976108000857982
# Calinski-Harabasz Score: 634.7002376391583
# Silhouette Score: 0.1159478922675564
#
# Number of clusters: 3
#
# OPTICS-5_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: 2.413447749412899
# Calinski-Harabasz Score: 829.111217511662
# Silhouette Score: 0.1459622257132174
#
# Number of clusters: 2
#
# OPTICS-5_1279_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.1142536232214404
# Calinski-Harabasz Score: 95.99774949214513
# Silhouette Score: -0.04223599067320739
#
# Number of clusters: 20
#
# OPTICS-5_1279_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.187023175014676
# Calinski-Harabasz Score: 228.05650913320878
# Silhouette Score: 0.0322082053275075
#
# Number of clusters: 7
#
# OPTICS-5_1279_500 Clustering Evaluation:
# Davies-Bouldin Score: 2.5797616988463288
# Calinski-Harabasz Score: 589.9891424983324
# Silhouette Score: 0.1142820972823619
#
# Number of clusters: 3
#
# OPTICS-5_1279_1000 Clustering Evaluation:
# Davies-Bouldin Score: 2.635070746688976
# Calinski-Harabasz Score: 794.6330043263167
# Silhouette Score: 0.13890680034481992
#
# Number of clusters: 2
#
# OPTICS-50_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.938909468730664
# Calinski-Harabasz Score: 161.44417283920066
# Silhouette Score: 0.12212137846391388
#
# Number of clusters: 22
#
# OPTICS-50_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.6942773425244384
# Calinski-Harabasz Score: 339.74087811252167
# Silhouette Score: 0.20723399008252752
#
# Number of clusters: 9
#
# OPTICS-50_3_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9961478867265781
# Calinski-Harabasz Score: 722.2583090808957
# Silhouette Score: 0.20509031909477038
#
# Number of clusters: 3
#
# OPTICS-50_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: 2.0296063037832184
# Calinski-Harabasz Score: 947.7336915937623
# Silhouette Score: 0.1655178774369281
#
# Number of clusters: 2
#
# OPTICS-50_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.960875388945373
# Calinski-Harabasz Score: 103.2605088869483
# Silhouette Score: -0.07695536473395952
#
# Number of clusters: 22
#
# OPTICS-50_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.8279078943102445
# Calinski-Harabasz Score: 392.7421189868039
# Silhouette Score: 0.206870308129799
#
# Number of clusters: 10
#
# OPTICS-50_5_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9961478867265781
# Calinski-Harabasz Score: 722.2583090808957
# Silhouette Score: 0.20509031909477038
#
# Number of clusters: 3
#
# OPTICS-50_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# OPTICS-50_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.9436928387925834
# Calinski-Harabasz Score: 104.3415865989006
# Silhouette Score: -0.08653740062646446
#
# Number of clusters: 22
#
# OPTICS-50_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.5190356215335448
# Calinski-Harabasz Score: 386.18391516665986
# Silhouette Score: 0.17206998465061368
#
# Number of clusters: 8
#
# OPTICS-50_20_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9961478867265781
# Calinski-Harabasz Score: 722.2583090808957
# Silhouette Score: 0.20509031909477038
#
# Number of clusters: 3
#
# OPTICS-50_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# OPTICS-50_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.8774159622588518
# Calinski-Harabasz Score: 205.71910017013897
# Silhouette Score: 0.21046975241151666
#
# Number of clusters: 21
#
# OPTICS-50_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.7348508593488248
# Calinski-Harabasz Score: 327.9547642198607
# Silhouette Score: 0.1744147475290785
#
# Number of clusters: 10
#
# OPTICS-50_50_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9961478867265781
# Calinski-Harabasz Score: 722.2583090808957
# Silhouette Score: 0.20509031909477038
#
# Number of clusters: 3
#
# OPTICS-50_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# OPTICS-50_1279_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.8549114320218023
# Calinski-Harabasz Score: 203.64514406466253
# Silhouette Score: 0.19894611979781907
#
# Number of clusters: 21

# %%
n_neighbors = 50
n_components  = features.shape[1]
for min_cluster_size in (100, 500, 1000):
  cluster_labels = generate_clusters(features,
      n_neighbors, n_components, min_cluster_size)
  evaluate_clustering(f"OPTICS-{n_neighbors}_{n_components}_{min_cluster_size}", features, cluster_labels)
# Out:
# OPTICS-50_1279_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.1560312911442618
# Calinski-Harabasz Score: 418.8604102838821
# Silhouette Score: 0.24916451901881947
#
# Number of clusters: 7
#
# OPTICS-50_1279_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9961478867265781
# Calinski-Harabasz Score: 722.2583090808957
# Silhouette Score: 0.20509031909477038
#
# Number of clusters: 3
#
# OPTICS-50_1279_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1

# %%
n_neighbors  = 100
for n_components in (3, 5, 20 , 50, features.shape[1]):
  for min_cluster_size in (50, 100, 500, 1000):
    cluster_labels = generate_clusters(features,
        n_neighbors, n_components, min_cluster_size)
    evaluate_clustering(f"OPTICS-{n_neighbors}_{n_components}_{min_cluster_size}", features, cluster_labels)
# Out:
# OPTICS-100_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.2084976966548293
# Calinski-Harabasz Score: 200.65830831466408
# Silhouette Score: 0.22893615048893493
#
# Number of clusters: 26
#
# OPTICS-100_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.6535060388585554
# Calinski-Harabasz Score: 411.4412549272748
# Silhouette Score: 0.24748169732331174
#
# Number of clusters: 7
#
# OPTICS-100_3_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9920219927797796
# Calinski-Harabasz Score: 722.3548224944866
# Silhouette Score: 0.20502413243888137
#
# Number of clusters: 3
#
# OPTICS-100_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# OPTICS-100_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.645165838247916
# Calinski-Harabasz Score: 249.87481501040787
# Silhouette Score: 0.20901938256428648
#
# Number of clusters: 12
#
# OPTICS-100_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.5521434337885551
# Calinski-Harabasz Score: 423.35325729592574
# Silhouette Score: 0.22797588761901313
#
# Number of clusters: 7
#
# OPTICS-100_5_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9912969411410485
# Calinski-Harabasz Score: 722.3693660020681
# Silhouette Score: 0.20510529909319208
#
# Number of clusters: 3
#
# OPTICS-100_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# OPTICS-100_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.5357720869827738
# Calinski-Harabasz Score: 249.85483666862257
# Silhouette Score: 0.20925665366964719
#
# Number of clusters: 12
#
# OPTICS-100_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.268316449776528
# Calinski-Harabasz Score: 424.0352051693936
# Silhouette Score: 0.2331243846238052
#
# Number of clusters: 7
#
# OPTICS-100_20_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9920219927797796
# Calinski-Harabasz Score: 722.3548224944866
# Silhouette Score: 0.20502413243888137
#
# Number of clusters: 3
#
# OPTICS-100_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# OPTICS-100_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.2202251180585075
# Calinski-Harabasz Score: 231.02429967929118
# Silhouette Score: 0.25047978545761235
#
# Number of clusters: 24
#
# OPTICS-100_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.46221477155084
# Calinski-Harabasz Score: 414.27733561778103
# Silhouette Score: 0.25024193267256173
#
# Number of clusters: 7
#
# OPTICS-100_50_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9920219927797796
# Calinski-Harabasz Score: 722.3548224944866
# Silhouette Score: 0.20502413243888137
#
# Number of clusters: 3
#
# OPTICS-100_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# OPTICS-100_1279_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.4979261912787862
# Calinski-Harabasz Score: 253.2288289357276
# Silhouette Score: 0.21125381816709995
#
# Number of clusters: 12
#
# OPTICS-100_1279_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.266632616553969
# Calinski-Harabasz Score: 423.9988529866302
# Silhouette Score: 0.23321520203123777
#
# Number of clusters: 7
#
# OPTICS-100_1279_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9920219927797796
# Calinski-Harabasz Score: 722.3548224944866
# Silhouette Score: 0.20502413243888137
#
# Number of clusters: 3
#
# OPTICS-100_1279_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1

# %%
def generate_clusters(message_embeddings,
                    n_neighbors,
                    n_components,
                    min_cluster_size,
                    random_state = None):
  """
  Generate HDBSCAN cluster object after reducing embedding dimensionality with UMAP
  """

  umap_embeddings = (umap.UMAP(n_neighbors=n_neighbors,
                              n_components=n_components,
                              metric='cosine',
                              random_state=random_state)
                          .fit_transform(message_embeddings))

  clusters = HDBSCAN(min_samples = min_cluster_size,
                              metric='euclidean').fit_predict(umap_embeddings)

  return clusters

# %%
for n_neighbors in (5, 50, 100):
  for n_components in (3, 5, 20 , 50, features.shape[1]):
    for min_cluster_size in (50, 100, 500, 1000):
      cluster_labels = generate_clusters(features,
          n_neighbors, n_components, min_cluster_size)
      evaluate_clustering(f"HBDBSCAN-{n_neighbors}_{n_components}_{min_cluster_size}", features, cluster_labels)
# Out:
# HBDBSCAN-5_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.9830405989950919
# Calinski-Harabasz Score: 217.7524910487364
# Silhouette Score: 0.18846609958485863
#
# Number of clusters: 16
#
# HBDBSCAN-5_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.0484840862658187
# Calinski-Harabasz Score: 249.75098978047745
# Silhouette Score: 0.023660844221505738
#
# Number of clusters: 11
#
# HBDBSCAN-5_3_500 Clustering Evaluation:
# Davies-Bouldin Score: 2.3408409711332827
# Calinski-Harabasz Score: 767.1999881722468
# Silhouette Score: 0.1766889176583404
#
# Number of clusters: 3
#
# HBDBSCAN-5_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-5_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.093135962126868
# Calinski-Harabasz Score: 222.72310814822927
# Silhouette Score: 0.16826886705956984
#
# Number of clusters: 16
#
# HBDBSCAN-5_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.33488566334578
# Calinski-Harabasz Score: 300.9994769425195
# Silhouette Score: -0.07766509517729644
#
# Number of clusters: 8
#
# HBDBSCAN-5_5_500 Clustering Evaluation:
# Davies-Bouldin Score: 2.384751421903396
# Calinski-Harabasz Score: 644.4555481759463
# Silhouette Score: 0.14731501233784772
#
# Number of clusters: 3
#
# HBDBSCAN-5_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-5_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.9545424026874494
# Calinski-Harabasz Score: 212.1453298892951
# Silhouette Score: 0.1262924455404062
#
# Number of clusters: 15
#
# HBDBSCAN-5_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.4159299136052983
# Calinski-Harabasz Score: 377.6226624885343
# Silhouette Score: 0.2124843682740244
#
# Number of clusters: 8
#
# HBDBSCAN-5_20_500 Clustering Evaluation:
# Davies-Bouldin Score: 2.4228992926414192
# Calinski-Harabasz Score: 669.3766795853394
# Silhouette Score: 0.16026995065830707
#
# Number of clusters: 3
#
# HBDBSCAN-5_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-5_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.092009038635571
# Calinski-Harabasz Score: 199.78436651181053
# Silhouette Score: 0.14446392361834334
#
# Number of clusters: 17
#
# HBDBSCAN-5_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.191906939746789
# Calinski-Harabasz Score: 415.18252760053224
# Silhouette Score: 0.1811061850075714
#
# Number of clusters: 6
#
# HBDBSCAN-5_50_500 Clustering Evaluation:
# Davies-Bouldin Score: 2.462444838386675
# Calinski-Harabasz Score: 625.8225228548739
# Silhouette Score: 0.1530579765620753
#
# Number of clusters: 3
#
# HBDBSCAN-5_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-5_1279_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.132888834294123
# Calinski-Harabasz Score: 95.43531386923515
# Silhouette Score: 0.01575584809755638
#
# Number of clusters: 23
#
# HBDBSCAN-5_1279_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.3163320494045627
# Calinski-Harabasz Score: 383.58953476290617
# Silhouette Score: 0.16024940274629879
#
# Number of clusters: 6
#
# HBDBSCAN-5_1279_500 Clustering Evaluation:
# Davies-Bouldin Score: 2.2444669160842423
# Calinski-Harabasz Score: 638.7702972396319
# Silhouette Score: 0.1458620498516191
#
# Number of clusters: 3
#
# HBDBSCAN-5_1279_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-50_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.201522692223459
# Calinski-Harabasz Score: 197.12018950779893
# Silhouette Score: 0.22191791107451211
#
# Number of clusters: 26
#
# HBDBSCAN-50_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.1573904445198355
# Calinski-Harabasz Score: 428.8772589548869
# Silhouette Score: 0.2506261861839952
#
# Number of clusters: 7
#
# HBDBSCAN-50_3_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9961478867265781
# Calinski-Harabasz Score: 722.2583090808957
# Silhouette Score: 0.20509031909477038
#
# Number of clusters: 3
#
# HBDBSCAN-50_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-50_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.2252015214449994
# Calinski-Harabasz Score: 207.56216334459603
# Silhouette Score: 0.24707874483969963
#
# Number of clusters: 27
#
# HBDBSCAN-50_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.1444254401731455
# Calinski-Harabasz Score: 400.77008584981456
# Silhouette Score: 0.2470117074212129
#
# Number of clusters: 8
#
# HBDBSCAN-50_5_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.6449217581585778
# Calinski-Harabasz Score: 726.4610832041512
# Silhouette Score: 0.20179630496000708
#
# Number of clusters: 3
#
# HBDBSCAN-50_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-50_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.226829757258376
# Calinski-Harabasz Score: 215.6334754898012
# Silhouette Score: 0.24025591623057538
#
# Number of clusters: 24
#
# HBDBSCAN-50_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.1585608477785194
# Calinski-Harabasz Score: 418.7693450800708
# Silhouette Score: 0.24903938568618958
#
# Number of clusters: 7
#
# HBDBSCAN-50_20_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9961478867265781
# Calinski-Harabasz Score: 722.2583090808957
# Silhouette Score: 0.20509031909477038
#
# Number of clusters: 3
#
# HBDBSCAN-50_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-50_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.7528897795498979
# Calinski-Harabasz Score: 245.02961045443595
# Silhouette Score: 0.21418376942472633
#
# Number of clusters: 14
#
# HBDBSCAN-50_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.157939509609476
# Calinski-Harabasz Score: 418.6087545690319
# Silhouette Score: 0.24903105724755173
#
# Number of clusters: 7
#
# HBDBSCAN-50_50_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.4006294151824814
# Calinski-Harabasz Score: 708.5271868777274
# Silhouette Score: 0.20228543239621558
#
# Number of clusters: 3
#
# HBDBSCAN-50_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-50_1279_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.4747035650380524
# Calinski-Harabasz Score: 249.52990032999617
# Silhouette Score: 0.2072424844803521
#
# Number of clusters: 12
#
# HBDBSCAN-50_1279_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.1576303835628956
# Calinski-Harabasz Score: 418.6524514586073
# Silhouette Score: 0.2490158643564001
#
# Number of clusters: 7
#
# HBDBSCAN-50_1279_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9968723933071635
# Calinski-Harabasz Score: 722.2438629279734
# Silhouette Score: 0.20500925200711392
#
# Number of clusters: 3

# %%
n_neighbors = 50
n_components = features.shape[1]
min_cluster_size = 1000
cluster_labels = generate_clusters(features,
          n_neighbors, n_components, min_cluster_size)
evaluate_clustering(f"HBDBSCAN-{n_neighbors}_{n_components}_{min_cluster_size}", features, cluster_labels)
# Out:
# HBDBSCAN-50_1279_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1

# %%
n_neighbors = 100
for n_components in (3, 5, 20 , 50, features.shape[1]):
  for min_cluster_size in (50, 100, 500, 1000):
    cluster_labels = generate_clusters(features,
        n_neighbors, n_components, min_cluster_size)
    evaluate_clustering(f"HBDBSCAN-{n_neighbors}_{n_components}_{min_cluster_size}", features, cluster_labels)
# Out:
# HBDBSCAN-100_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.20667011451865
# Calinski-Harabasz Score: 208.57102865884718
# Silhouette Score: 0.22755861958287266
#
# Number of clusters: 25
#
# HBDBSCAN-100_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.5646809774271373
# Calinski-Harabasz Score: 439.99816860511095
# Silhouette Score: 0.23036850050769023
#
# Number of clusters: 6
#
# HBDBSCAN-100_3_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9912969411410485
# Calinski-Harabasz Score: 722.3693660020681
# Silhouette Score: 0.20510529909319208
#
# Number of clusters: 3
#
# HBDBSCAN-100_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-100_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.434619124274161
# Calinski-Harabasz Score: 253.12569284324493
# Silhouette Score: 0.21021587379186615
#
# Number of clusters: 12
#
# HBDBSCAN-100_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.509144472317619
# Calinski-Harabasz Score: 408.99395407233715
# Silhouette Score: 0.2468647394965948
#
# Number of clusters: 7
#
# HBDBSCAN-100_5_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9912969411410485
# Calinski-Harabasz Score: 722.3693660020681
# Silhouette Score: 0.20510529909319208
#
# Number of clusters: 3
#
# HBDBSCAN-100_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-100_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.6938679727441173
# Calinski-Harabasz Score: 248.69140024533172
# Silhouette Score: 0.2055708667131845
#
# Number of clusters: 12
#
# HBDBSCAN-100_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.3169108260728748
# Calinski-Harabasz Score: 461.94304938873023
# Silhouette Score: 0.24781700492863298
#
# Number of clusters: 6
#
# HBDBSCAN-100_20_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9920219927797796
# Calinski-Harabasz Score: 722.3548224944866
# Silhouette Score: 0.20502413243888137
#
# Number of clusters: 3
#
# HBDBSCAN-100_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-100_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.13546747586655
# Calinski-Harabasz Score: 204.21080783350814
# Silhouette Score: 0.22096852523196653
#
# Number of clusters: 25
#
# HBDBSCAN-100_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.3188729894032802
# Calinski-Harabasz Score: 459.96397662721307
# Silhouette Score: 0.2474292541729362
#
# Number of clusters: 6
#
# HBDBSCAN-100_50_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9920219927797796
# Calinski-Harabasz Score: 722.3548224944866
# Silhouette Score: 0.20502413243888137
#
# Number of clusters: 3
#
# HBDBSCAN-100_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-100_1279_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.6513121723459736
# Calinski-Harabasz Score: 250.75782251368642
# Silhouette Score: 0.20549565347344775
#
# Number of clusters: 12
#
# HBDBSCAN-100_1279_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.202452762456135
# Calinski-Harabasz Score: 564.064669353133
# Silhouette Score: 0.2463205467074087
#
# Number of clusters: 5
#
# HBDBSCAN-100_1279_500 Clustering Evaluation:
# Davies-Bouldin Score: 0.9912969411410485
# Calinski-Harabasz Score: 722.3693660020681
# Silhouette Score: 0.20510529909319208
#
# Number of clusters: 3
#
# HBDBSCAN-100_1279_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1

# %%
print('Finished')
# Out:
# Finished

# %%
print("process")
# Out:
# process
