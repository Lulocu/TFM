# %%
# !pip install umap-learn
# Out:
# Collecting umap-learn
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 830.3 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.23.5)
# Requirement already satisfied: scikit-learn>=0.22 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.2.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (1.10.1)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.10/dist-packages (from umap-learn) (0.56.4)
# Collecting pynndescent>=0.5 (from umap-learn)
#   Downloading pynndescent-0.5.10.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from umap-learn) (4.66.1)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from numba>=0.49->umap-learn) (67.7.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from pynndescent>=0.5->umap-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22->umap-learn) (3.2.0)
# Building wheels for collected packages: umap-learn, pynndescent
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82807 sha256=33d71ffb47b4b0a78204a3b6b9ee6db10bf40972d964f2330d14db56ee60fb86
#   Stored in directory: /root/.cache/pip/wheels/a0/e8/c6/a37ea663620bd5200ea1ba0907ab3c217042c1d035ef606acc
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.10-py3-none-any.whl size=55615 sha256=f33c73bf93307a54a2362014b050ae41d1e6d3afcb5dc3ab224b47339790bc74
#   Stored in directory: /root/.cache/pip/wheels/4a/38/5d/f60a40a66a9512b7e5e83517ebc2d1b42d857be97d135f1096
# Successfully built umap-learn pynndescent
# Installing collected packages: pynndescent, umap-learn
# Successfully installed pynndescent-0.5.10 umap-learn-0.5.3

# %%
# !pip install --upgrade scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 22.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.2.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# Successfully installed scikit-learn-1.3.0

# %%
from sklearn.cluster import HDBSCAN

# %%
from sklearn.cluster import DBSCAN, OPTICS

import pandas as pd
from google.colab import drive
import umap
import matplotlib.pyplot as plt
from sklearn.metrics import davies_bouldin_score, calinski_harabasz_score, silhouette_score

# %%
drive.mount('/content/drive')

#input_path="/content/drive/MyDrive/TFM/Instagram.Post.json"

data = pd.read_csv('/content/drive/MyDrive/TFM/Embeddings/SentenceEmbeddings.csv', header=None)
ids = data.iloc[:, 0]
features = data.iloc[:, 1:]
# Out:
# Mounted at /content/drive

# %%
def generate_clusters(message_embeddings,
                    n_neighbors,
                    n_components,
                    min_cluster_size,
                    random_state = None):
  """
  Generate HDBSCAN cluster object after reducing embedding dimensionality with UMAP
  """

  umap_embeddings = (umap.UMAP(n_neighbors=n_neighbors,
                              n_components=n_components,
                              metric='cosine',
                              random_state=random_state)
                          .fit_transform(message_embeddings))

  clusters = DBSCAN(min_samples = min_cluster_size,
                              metric='euclidean').fit_predict(umap_embeddings)

  return clusters

# %%
def evaluate_clustering(title, features, labels):
    """
    Calculate clustering evaluation metrics for a given clustering result and print the results.

    Parameters:
    - title: A string, title for the clustering result.
    - features: Features used for clustering (numpy array or DataFrame).
    - labels: Cluster labels assigned by the clustering algorithm.
    """
    try:
      davies_bouldin = davies_bouldin_score(features, labels)
    except:
      davies_bouldin = 'Not applicable'

    try:
      calinski_harabasz = calinski_harabasz_score(features, labels)
    except:
      calinski_harabasz = 'Not applicable'

    try:
      silhouette = silhouette_score(features, labels)
    except:
      silhouette = 'Not applicable'

    try:
      n_clusters = len(set(labels))
    except:
      n_clusters = 'Not applicable'

    print(f"{title} Clustering Evaluation:")
    print(f"Davies-Bouldin Score: {davies_bouldin}")
    print(f"Calinski-Harabasz Score: {calinski_harabasz}")
    print(f"Silhouette Score: {silhouette}\n")
    print(f"Number of clusters: {n_clusters}\n")

# %%
for n_neighbors in (5, 50, 100):
  for n_components in (3, 5, 20 , 50,features.shape[1]):
    for min_cluster_size in (50, 100, 500, 1000):
      cluster_labels = generate_clusters(features,
          n_neighbors, n_components, min_cluster_size)
      evaluate_clustering(f"DBSCAN-{n_neighbors}_{n_components}_{min_cluster_size}", features, cluster_labels)
# Out:
# DBSCAN-5_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 3.3170726504817867
# Calinski-Harabasz Score: 93.96757986612934
# Silhouette Score: 0.16649838575937254
#
# Number of clusters: 27
#
# DBSCAN-5_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.7355923554744428
# Calinski-Harabasz Score: 368.1767547040512
# Silhouette Score: 0.1246898732788121
#
# Number of clusters: 4
#
# DBSCAN-5_3_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 3.1760045257356175
# Calinski-Harabasz Score: 92.79588249182603
# Silhouette Score: 0.15924010176934753
#
# Number of clusters: 27
#
# DBSCAN-5_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.7344873692297487
# Calinski-Harabasz Score: 364.0149505544522
# Silhouette Score: 0.12203940435908193
#
# Number of clusters: 4
#
# DBSCAN-5_5_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 3.487246116409509
# Calinski-Harabasz Score: 86.96178670392942
# Silhouette Score: 0.17176557026194061
#
# Number of clusters: 30
#
# DBSCAN-5_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.81575366902998
# Calinski-Harabasz Score: 336.92844818397657
# Silhouette Score: 0.10878864327443873
#
# Number of clusters: 4
#
# DBSCAN-5_20_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 3.229163057445617
# Calinski-Harabasz Score: 87.76553600309812
# Silhouette Score: 0.17274570894353444
#
# Number of clusters: 31
#
# DBSCAN-5_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.777742819525483
# Calinski-Harabasz Score: 354.4232287561662
# Silhouette Score: 0.11323014126786758
#
# Number of clusters: 4
#
# DBSCAN-5_50_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_384_50 Clustering Evaluation:
# Davies-Bouldin Score: 3.048689916278396
# Calinski-Harabasz Score: 96.22671354918216
# Silhouette Score: 0.14741332520706715
#
# Number of clusters: 25
#
# DBSCAN-5_384_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.7834519660506645
# Calinski-Harabasz Score: 361.3580863216045
# Silhouette Score: 0.123243578384829
#
# Number of clusters: 4
#
# DBSCAN-5_384_500 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-5_384_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-50_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.3718953331805515
# Calinski-Harabasz Score: 158.038623917323
# Silhouette Score: 0.20783745003743687
#
# Number of clusters: 17
#
# DBSCAN-50_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 3.0156715762416035
# Calinski-Harabasz Score: 222.52894918930548
# Silhouette Score: 0.17119051863408574
#
# Number of clusters: 10
#
# DBSCAN-50_3_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1070666293663163
# Calinski-Harabasz Score: 736.7043073272255
# Silhouette Score: 0.11404046183838956
#
# Number of clusters: 2
#
# DBSCAN-50_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-50_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.4558453033536907
# Calinski-Harabasz Score: 166.17078771201588
# Silhouette Score: 0.20596208156012163
#
# Number of clusters: 16
#
# DBSCAN-50_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 3.1858907396724927
# Calinski-Harabasz Score: 205.63469396615235
# Silhouette Score: 0.17464127498338897
#
# Number of clusters: 11
#
# DBSCAN-50_5_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1072694213327325
# Calinski-Harabasz Score: 732.4475326085231
# Silhouette Score: 0.11280535772341582
#
# Number of clusters: 2
#
# DBSCAN-50_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-50_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.4832229898175733
# Calinski-Harabasz Score: 151.48425743302596
# Silhouette Score: 0.2073325610226797
#
# Number of clusters: 18
#
# DBSCAN-50_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 3.0516258452829286
# Calinski-Harabasz Score: 221.7901066904022
# Silhouette Score: 0.17246145343229283
#
# Number of clusters: 10
#
# DBSCAN-50_20_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1080471509184442
# Calinski-Harabasz Score: 718.6708569512901
# Silhouette Score: 0.10876689334014225
#
# Number of clusters: 2
#
# DBSCAN-50_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-50_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.469694524649687
# Calinski-Harabasz Score: 158.86450193712452
# Silhouette Score: 0.20716690590652964
#
# Number of clusters: 17
#
# DBSCAN-50_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 3.1371059134898407
# Calinski-Harabasz Score: 205.50748972898992
# Silhouette Score: 0.17424908093708874
#
# Number of clusters: 11
#
# DBSCAN-50_50_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1071361111436635
# Calinski-Harabasz Score: 719.8653791059007
# Silhouette Score: 0.10920239961806559
#
# Number of clusters: 2
#
# DBSCAN-50_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-50_384_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.4690726163171
# Calinski-Harabasz Score: 158.47514412637028
# Silhouette Score: 0.20695292944114144
#
# Number of clusters: 17
#
# DBSCAN-50_384_100 Clustering Evaluation:
# Davies-Bouldin Score: 3.1517786209118213
# Calinski-Harabasz Score: 204.71877020773786
# Silhouette Score: 0.17350072545035686
#
# Number of clusters: 11
#
# DBSCAN-50_384_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1075685192557874
# Calinski-Harabasz Score: 717.7036247342261
# Silhouette Score: 0.10853437462885583
#
# Number of clusters: 2
#
# DBSCAN-50_384_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-100_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.3730325989677787
# Calinski-Harabasz Score: 161.09989245694246
# Silhouette Score: 0.2024048279301741
#
# Number of clusters: 17
#
# DBSCAN-100_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.9928938047333373
# Calinski-Harabasz Score: 261.44154030811313
# Silhouette Score: 0.1635901182206103
#
# Number of clusters: 8
#
# DBSCAN-100_3_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1092726252179466
# Calinski-Harabasz Score: 725.8034671242335
# Silhouette Score: 0.1107013314856712
#
# Number of clusters: 2
#
# DBSCAN-100_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-100_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.4573944198627675
# Calinski-Harabasz Score: 156.466318736431
# Silhouette Score: 0.2097298993532634
#
# Number of clusters: 18
#
# DBSCAN-100_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 3.210474847651787
# Calinski-Harabasz Score: 211.45091812515255
# Silhouette Score: 0.17573204773578652
#
# Number of clusters: 11
#
# DBSCAN-100_5_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.10794899563082
# Calinski-Harabasz Score: 732.3343795838018
# Silhouette Score: 0.11270481375043824
#
# Number of clusters: 2
#
# DBSCAN-100_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-100_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.42620189179207
# Calinski-Harabasz Score: 152.89720227567844
# Silhouette Score: 0.20455184245581523
#
# Number of clusters: 18
#
# DBSCAN-100_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 3.1617196358006625
# Calinski-Harabasz Score: 209.86413054832073
# Silhouette Score: 0.17466167901357632
#
# Number of clusters: 11
#
# DBSCAN-100_20_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1114447701809547
# Calinski-Harabasz Score: 711.8629652417987
# Silhouette Score: 0.10646058888463951
#
# Number of clusters: 2
#
# DBSCAN-100_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-100_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.4722046995976648
# Calinski-Harabasz Score: 155.91408256498735
# Silhouette Score: 0.2094771490036971
#
# Number of clusters: 18
#
# DBSCAN-100_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 3.1728974842957585
# Calinski-Harabasz Score: 207.42893396886743
# Silhouette Score: 0.17346195553377658
#
# Number of clusters: 11
#
# DBSCAN-100_50_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1119202981288667
# Calinski-Harabasz Score: 712.8272760609702
# Silhouette Score: 0.10669433658944341
#
# Number of clusters: 2
#
# DBSCAN-100_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# DBSCAN-100_384_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.4598978599172416
# Calinski-Harabasz Score: 154.15717761153633
# Silhouette Score: 0.20619389377326564
#
# Number of clusters: 18
#
# DBSCAN-100_384_100 Clustering Evaluation:
# Davies-Bouldin Score: 3.2061879332389607
# Calinski-Harabasz Score: 210.61597095555976
# Silhouette Score: 0.17538968437795735
#
# Number of clusters: 11
#
# DBSCAN-100_384_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1162205018723603
# Calinski-Harabasz Score: 685.3185683365527
# Silhouette Score: 0.09821199418542174
#
# Number of clusters: 2
#
# DBSCAN-100_384_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1

# %%
def generate_clusters(message_embeddings,
                    n_neighbors,
                    n_components,
                    min_cluster_size,
                    random_state = None):
  """
  Generate HDBSCAN cluster object after reducing embedding dimensionality with UMAP
  """

  umap_embeddings = (umap.UMAP(n_neighbors=n_neighbors,
                              n_components=n_components,
                              metric='cosine',
                              random_state=random_state)
                          .fit_transform(message_embeddings))

  clusters = OPTICS(min_samples = min_cluster_size
                        ).fit_predict(umap_embeddings)

  return clusters

# %%
for n_neighbors in (5, 50, 100):
  for n_components in (3, 5, 20 , 50, features.shape[1]):
    for min_cluster_size in (50, 100, 500, 1000):
      cluster_labels = generate_clusters(features,
          n_neighbors, n_components, min_cluster_size)
      evaluate_clustering(f"OPTICS-{n_neighbors}_{n_components}_{min_cluster_size}", features, cluster_labels)
# Out:
# OPTICS-5_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 3.1853446584265397
# Calinski-Harabasz Score: 88.53464139677206
# Silhouette Score: 0.18066243945923352
#
# Number of clusters: 30
#
# OPTICS-5_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.683226007474018
# Calinski-Harabasz Score: 195.80115753077797
# Silhouette Score: 0.15187148861416316
#
# Number of clusters: 10
#
# OPTICS-5_3_500 Clustering Evaluation:
# Davies-Bouldin Score: 4.269406571640412
# Calinski-Harabasz Score: 450.17411865116674
# Silhouette Score: 0.12153229862277119
#
# Number of clusters: 3
#
# OPTICS-5_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: 4.174773567577285
# Calinski-Harabasz Score: 323.5482790448955
# Silhouette Score: 0.08070564529390488
#
# Number of clusters: 2
#
# OPTICS-5_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 3.1058101945061494
# Calinski-Harabasz Score: 93.5019466003142
# Silhouette Score: 0.17738514577428793
#
# Number of clusters: 28
#
# OPTICS-5_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.9857619919161706
# Calinski-Harabasz Score: 174.28451833196078
# Silhouette Score: 0.14049615946622118
#
# Number of clusters: 10
#
# OPTICS-5_5_500 Clustering Evaluation:
# Davies-Bouldin Score: 3.3015296892808936
# Calinski-Harabasz Score: 467.2811455307079
# Silhouette Score: 0.12857236906723693
#
# Number of clusters: 3
#
# OPTICS-5_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# OPTICS-5_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.9627957389304047
# Calinski-Harabasz Score: 94.99182568111051
# Silhouette Score: 0.17900171998354564
#
# Number of clusters: 29
#
# OPTICS-5_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 3.3012434629093237
# Calinski-Harabasz Score: 201.3894724433004
# Silhouette Score: 0.15760918664764503
#
# Number of clusters: 10
#
# OPTICS-5_20_500 Clustering Evaluation:
# Davies-Bouldin Score: 3.008748946916986
# Calinski-Harabasz Score: 476.9794214764907
# Silhouette Score: 0.12979514920182425
#
# Number of clusters: 3
#
# OPTICS-5_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: 4.081531500108208
# Calinski-Harabasz Score: 334.8826751547692
# Silhouette Score: 0.08153490499324571
#
# Number of clusters: 2
#
# OPTICS-5_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 3.338558130753633
# Calinski-Harabasz Score: 98.06053740924521
# Silhouette Score: 0.17447978376845574
#
# Number of clusters: 25
#
# OPTICS-5_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.5941096320849635
# Calinski-Harabasz Score: 204.92644220309828
# Silhouette Score: 0.14166355211653325
#
# Number of clusters: 9
#
# OPTICS-5_50_500 Clustering Evaluation:
# Davies-Bouldin Score: 3.817719509691525
# Calinski-Harabasz Score: 466.5899779985219
# Silhouette Score: 0.12499471098712012
#
# Number of clusters: 3
#
# OPTICS-5_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: 3.261302429698632
# Calinski-Harabasz Score: 456.41391407298386
# Silhouette Score: 0.0907583353418273
#
# Number of clusters: 2
#
# OPTICS-5_384_50 Clustering Evaluation:
# Davies-Bouldin Score: 3.1158460458347195
# Calinski-Harabasz Score: 94.46566217712362
# Silhouette Score: 0.17900279189631446
#
# Number of clusters: 29
#
# OPTICS-5_384_100 Clustering Evaluation:
# Davies-Bouldin Score: 3.3634602536648677
# Calinski-Harabasz Score: 231.45156587044102
# Silhouette Score: 0.13851877540931637
#
# Number of clusters: 8
#
# OPTICS-5_384_500 Clustering Evaluation:
# Davies-Bouldin Score: 3.856806459824888
# Calinski-Harabasz Score: 464.2850963841164
# Silhouette Score: 0.12488966320600024
#
# Number of clusters: 3
#
# OPTICS-5_384_1000 Clustering Evaluation:
# Davies-Bouldin Score: 4.63955546563599
# Calinski-Harabasz Score: 262.22509539234045
# Silhouette Score: 0.07630267496024434
#
# Number of clusters: 2
#
# OPTICS-50_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.2709719087938947
# Calinski-Harabasz Score: 150.94024935370857
# Silhouette Score: 0.20931653953838564
#
# Number of clusters: 19
#
# OPTICS-50_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.0269675645474994
# Calinski-Harabasz Score: 230.82837800303653
# Silhouette Score: 0.16676716836841785
#
# Number of clusters: 9
#
# OPTICS-50_3_500 Clustering Evaluation:
# Davies-Bouldin Score: 4.048473915732395
# Calinski-Harabasz Score: 463.98673958620253
# Silhouette Score: 0.12898973010431997
#
# Number of clusters: 3
#
# OPTICS-50_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: 2.1783223204192557
# Calinski-Harabasz Score: 610.856391831502
# Silhouette Score: 0.09192507586186709
#
# Number of clusters: 2
#
# OPTICS-50_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.2260462920340176
# Calinski-Harabasz Score: 141.04490511180498
# Silhouette Score: 0.2095866764445256
#
# Number of clusters: 20
#
# OPTICS-50_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.24383930689663
# Calinski-Harabasz Score: 205.24162807352374
# Silhouette Score: 0.16464436617278277
#
# Number of clusters: 10
#
# OPTICS-50_5_500 Clustering Evaluation:
# Davies-Bouldin Score: 4.0312013142261724
# Calinski-Harabasz Score: 460.5882706136507
# Silhouette Score: 0.12850837308098365
#
# Number of clusters: 3
#
# OPTICS-50_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# OPTICS-50_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.0698430318375816
# Calinski-Harabasz Score: 152.3755177089968
# Silhouette Score: 0.20581440397065628
#
# Number of clusters: 18
#
# OPTICS-50_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.957507379431904
# Calinski-Harabasz Score: 235.3261528629929
# Silhouette Score: 0.16657463518825577
#
# Number of clusters: 9
#
# OPTICS-50_20_500 Clustering Evaluation:
# Davies-Bouldin Score: 4.033834122034542
# Calinski-Harabasz Score: 460.3673042705925
# Silhouette Score: 0.12847757447810892
#
# Number of clusters: 3
#
# OPTICS-50_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# OPTICS-50_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.206019255032751
# Calinski-Harabasz Score: 149.46392064790163
# Silhouette Score: 0.21891291697963192
#
# Number of clusters: 20
#
# OPTICS-50_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.812120572450299
# Calinski-Harabasz Score: 257.59741101433815
# Silhouette Score: 0.18557786482364683
#
# Number of clusters: 9
#
# OPTICS-50_50_500 Clustering Evaluation:
# Davies-Bouldin Score: 4.041567591677659
# Calinski-Harabasz Score: 464.05473136755955
# Silhouette Score: 0.1290464795867955
#
# Number of clusters: 3
#
# OPTICS-50_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# OPTICS-50_384_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.2454782982870842
# Calinski-Harabasz Score: 148.36574423223925
# Silhouette Score: 0.21577300056737486
#
# Number of clusters: 20
#
# OPTICS-50_384_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.860047728144269
# Calinski-Harabasz Score: 258.2110894409746
# Silhouette Score: 0.16519428605451666
#
# Number of clusters: 8
#
# OPTICS-50_384_500 Clustering Evaluation:
# Davies-Bouldin Score: 4.040210028739252
# Calinski-Harabasz Score: 464.1153747499569
# Silhouette Score: 0.1290693742084058
#
# Number of clusters: 3
#
# OPTICS-50_384_1000 Clustering Evaluation:
# Davies-Bouldin Score: 2.0104255570501435
# Calinski-Harabasz Score: 625.2015112697896
# Silhouette Score: 0.0979407065476286
#
# Number of clusters: 2
#
# OPTICS-100_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.0039590346907503
# Calinski-Harabasz Score: 151.82495482906742
# Silhouette Score: 0.20438285656856656
#
# Number of clusters: 18
#
# OPTICS-100_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.1308632652375232
# Calinski-Harabasz Score: 230.6781053207836
# Silhouette Score: 0.164723171912583
#
# Number of clusters: 9
#
# OPTICS-100_3_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1845067699494882
# Calinski-Harabasz Score: 730.7169459178813
# Silhouette Score: 0.11387631709994782
#
# Number of clusters: 2
#
# OPTICS-100_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# OPTICS-100_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.375501260193384
# Calinski-Harabasz Score: 156.58251650964252
# Silhouette Score: 0.2071957859403873
#
# Number of clusters: 18
#
# OPTICS-100_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.9986403655947766
# Calinski-Harabasz Score: 254.1337424551522
# Silhouette Score: 0.16468683682874172
#
# Number of clusters: 8
#
# OPTICS-100_5_500 Clustering Evaluation:
# Davies-Bouldin Score: 3.9940855832317026
# Calinski-Harabasz Score: 460.9435681614088
# Silhouette Score: 0.1286048043407896
#
# Number of clusters: 3

# %%
n_neighbors = 100
for n_components in (5, 20 , 50, features.shape[1]):
  for min_cluster_size in (50, 100, 500, 1000):
    cluster_labels = generate_clusters(features,
        n_neighbors, n_components, min_cluster_size)
    evaluate_clustering(f"OPTICS-{n_neighbors}_{n_components}_{min_cluster_size}", features, cluster_labels)
# Out:
# OPTICS-100_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.8589420554763156
# Calinski-Harabasz Score: 88.70595101369639
# Silhouette Score: -0.061390209855175716
#
# Number of clusters: 17
#
# OPTICS-100_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.8695017509144822
# Calinski-Harabasz Score: 292.8079961925879
# Silhouette Score: 0.18353770816243437
#
# Number of clusters: 8
#
# OPTICS-100_5_500 Clustering Evaluation:
# Davies-Bouldin Score: 2.3585660283619148
# Calinski-Harabasz Score: 506.9571250447822
# Silhouette Score: 0.1443428885525912
#
# Number of clusters: 3
#
# OPTICS-100_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# OPTICS-100_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.9777267170460553
# Calinski-Harabasz Score: 93.28798032785367
# Silhouette Score: -0.06537931631744394
#
# Number of clusters: 18
#
# OPTICS-100_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.0923961670376925
# Calinski-Harabasz Score: 230.7519228596769
# Silhouette Score: 0.16711827608605845
#
# Number of clusters: 9
#
# OPTICS-100_20_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1845067699494882
# Calinski-Harabasz Score: 730.7169459178813
# Silhouette Score: 0.11387631709994782
#
# Number of clusters: 2
#
# OPTICS-100_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# OPTICS-100_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.0181556439228983
# Calinski-Harabasz Score: 139.91964089346243
# Silhouette Score: 0.201587954304019
#
# Number of clusters: 19
#
# OPTICS-100_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.8774786870845381
# Calinski-Harabasz Score: 276.7891285983314
# Silhouette Score: 0.1744758123288599
#
# Number of clusters: 8
#
# OPTICS-100_50_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1845067699494882
# Calinski-Harabasz Score: 730.7169459178813
# Silhouette Score: 0.11387631709994782
#
# Number of clusters: 2
#
# OPTICS-100_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# OPTICS-100_384_50 Clustering Evaluation:
# Davies-Bouldin Score: 1.9874102510364753
# Calinski-Harabasz Score: 138.19164237695887
# Silhouette Score: 0.19011944007565687
#
# Number of clusters: 18
#
# OPTICS-100_384_100 Clustering Evaluation:
# Davies-Bouldin Score: 1.8640806352444372
# Calinski-Harabasz Score: 255.34238184010357
# Silhouette Score: 0.16152627067153916
#
# Number of clusters: 8
#
# OPTICS-100_384_500 Clustering Evaluation:
# Davies-Bouldin Score: 3.99364437828041
# Calinski-Harabasz Score: 461.2581974379031
# Silhouette Score: 0.12865120561263912
#
# Number of clusters: 3
#
# OPTICS-100_384_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1

# %%
def generate_clusters(message_embeddings,
                    n_neighbors,
                    n_components,
                    min_cluster_size,
                    random_state = None):
  """
  Generate HDBSCAN cluster object after reducing embedding dimensionality with UMAP
  """

  umap_embeddings = (umap.UMAP(n_neighbors=n_neighbors,
                              n_components=n_components,
                              metric='cosine',
                              random_state=random_state)
                          .fit_transform(message_embeddings))

  clusters = HDBSCAN(min_samples = min_cluster_size,
                              metric='euclidean').fit_predict(umap_embeddings)

  return clusters

# %%
for n_neighbors in (5, 50, 100):
  for n_components in (3, 5, 20 , 50, features.shape[1]):
    for min_cluster_size in (50, 100, 500, 1000):
      cluster_labels = generate_clusters(features,
          n_neighbors, n_components, min_cluster_size)
      evaluate_clustering(f"HBDBSCAN-{n_neighbors}_{n_components}_{min_cluster_size}", features, cluster_labels)
# Out:
# HBDBSCAN-5_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.915233452789762
# Calinski-Harabasz Score: 115.74163743421272
# Silhouette Score: 0.1844445417372538
#
# Number of clusters: 23
#
# HBDBSCAN-5_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.6848043440099625
# Calinski-Harabasz Score: 143.62924852031304
# Silhouette Score: 0.132048803418521
#
# Number of clusters: 13
#
# HBDBSCAN-5_3_500 Clustering Evaluation:
# Davies-Bouldin Score: 3.3705670253395206
# Calinski-Harabasz Score: 465.02879903979044
# Silhouette Score: 0.12807204035670064
#
# Number of clusters: 3
#
# HBDBSCAN-5_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-5_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.9089934513285947
# Calinski-Harabasz Score: 148.88906440322455
# Silhouette Score: 0.15958095299566732
#
# Number of clusters: 16
#
# HBDBSCAN-5_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.7884357764722014
# Calinski-Harabasz Score: 208.57904754739167
# Silhouette Score: 0.14498936268609763
#
# Number of clusters: 9
#
# HBDBSCAN-5_5_500 Clustering Evaluation:
# Davies-Bouldin Score: 2.768470018020473
# Calinski-Harabasz Score: 474.50360075010565
# Silhouette Score: 0.1293035867095019
#
# Number of clusters: 3
#
# HBDBSCAN-5_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-5_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.9562140697013097
# Calinski-Harabasz Score: 142.77211954991566
# Silhouette Score: 0.1727128179964987
#
# Number of clusters: 17
#
# HBDBSCAN-5_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.4881627107797364
# Calinski-Harabasz Score: 252.48427359523467
# Silhouette Score: 0.14047045637038352
#
# Number of clusters: 7
#
# HBDBSCAN-5_20_500 Clustering Evaluation:
# Davies-Bouldin Score: 2.742796447418989
# Calinski-Harabasz Score: 473.7919399443758
# Silhouette Score: 0.13150533978106257
#
# Number of clusters: 3
#
# HBDBSCAN-5_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-5_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.909260799176085
# Calinski-Harabasz Score: 140.569234121273
# Silhouette Score: 0.18473105439747364
#
# Number of clusters: 18
#
# HBDBSCAN-5_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 3.2479998783092916
# Calinski-Harabasz Score: 235.5633737786736
# Silhouette Score: 0.14236746346398246
#
# Number of clusters: 8
#
# HBDBSCAN-5_50_500 Clustering Evaluation:
# Davies-Bouldin Score: 2.8621701715796792
# Calinski-Harabasz Score: 467.2769098302882
# Silhouette Score: 0.1330537304410024
#
# Number of clusters: 3
#
# HBDBSCAN-5_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-5_384_50 Clustering Evaluation:
# Davies-Bouldin Score: 3.091415264173778
# Calinski-Harabasz Score: 117.32327442926372
# Silhouette Score: 0.159403436218759
#
# Number of clusters: 20
#
# HBDBSCAN-5_384_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.832048562907164
# Calinski-Harabasz Score: 268.2889012798065
# Silhouette Score: 0.14102924432559866
#
# Number of clusters: 7
#
# HBDBSCAN-5_384_500 Clustering Evaluation:
# Davies-Bouldin Score: 3.188658141859983
# Calinski-Harabasz Score: 448.94357736150226
# Silhouette Score: 0.12735339488914255
#
# Number of clusters: 3
#
# HBDBSCAN-5_384_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-50_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.4859046001287624
# Calinski-Harabasz Score: 159.61781298572362
# Silhouette Score: 0.21313834971598608
#
# Number of clusters: 18
#
# HBDBSCAN-50_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 3.221046706608246
# Calinski-Harabasz Score: 263.9202497158938
# Silhouette Score: 0.18971698452446947
#
# Number of clusters: 9
#
# HBDBSCAN-50_3_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.4367403750110486
# Calinski-Harabasz Score: 426.3858570733619
# Silhouette Score: 0.08016878748500822
#
# Number of clusters: 3
#
# HBDBSCAN-50_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-50_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.4193612512262126
# Calinski-Harabasz Score: 167.99254764272945
# Silhouette Score: 0.2143095074906176
#
# Number of clusters: 17
#
# HBDBSCAN-50_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 3.05864456901721
# Calinski-Harabasz Score: 253.64763416871386
# Silhouette Score: 0.18345072380216013
#
# Number of clusters: 9
#
# HBDBSCAN-50_5_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.4127398583689044
# Calinski-Harabasz Score: 420.66148144350984
# Silhouette Score: 0.07757545878530833
#
# Number of clusters: 3
#
# HBDBSCAN-50_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-50_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.175853511501264
# Calinski-Harabasz Score: 170.53183338151092
# Silhouette Score: 0.2078563511815084
#
# Number of clusters: 16
#
# HBDBSCAN-50_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.964796923160456
# Calinski-Harabasz Score: 228.62992825043582
# Silhouette Score: 0.1830248605518037
#
# Number of clusters: 10
#
# HBDBSCAN-50_20_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1889315097263584
# Calinski-Harabasz Score: 729.4436658376471
# Silhouette Score: 0.1138420625450591
#
# Number of clusters: 2
#
# HBDBSCAN-50_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-50_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.420889854947631
# Calinski-Harabasz Score: 168.96394563477782
# Silhouette Score: 0.21820754675334658
#
# Number of clusters: 17
#
# HBDBSCAN-50_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.909813083222027
# Calinski-Harabasz Score: 237.0108855989465
# Silhouette Score: 0.18903013721155335
#
# Number of clusters: 10
#
# HBDBSCAN-50_50_500 Clustering Evaluation:
# Davies-Bouldin Score: 2.1518752031848374
# Calinski-Harabasz Score: 490.86907827273365
# Silhouette Score: 0.12756487180195802
#
# Number of clusters: 3
#
# HBDBSCAN-50_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-50_384_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.449686041578327
# Calinski-Harabasz Score: 167.80127704047683
# Silhouette Score: 0.21462971656642185
#
# Number of clusters: 17
#
# HBDBSCAN-50_384_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.785376371961901
# Calinski-Harabasz Score: 237.1131251018238
# Silhouette Score: 0.18926392254419666
#
# Number of clusters: 10
#
# HBDBSCAN-50_384_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.257936590621946
# Calinski-Harabasz Score: 382.80730929364245
# Silhouette Score: 0.04182010858821322
#
# Number of clusters: 3
#
# HBDBSCAN-50_384_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-100_3_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.362578156986273
# Calinski-Harabasz Score: 167.1716686119032
# Silhouette Score: 0.21539852604177692
#
# Number of clusters: 17
#
# HBDBSCAN-100_3_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.9416830464795436
# Calinski-Harabasz Score: 252.3092549277774
# Silhouette Score: 0.18110879208575345
#
# Number of clusters: 9
#
# HBDBSCAN-100_3_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1879515174508213
# Calinski-Harabasz Score: 729.9580973977437
# Silhouette Score: 0.11385086269795233
#
# Number of clusters: 2
#
# HBDBSCAN-100_3_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-100_5_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.400273176754852
# Calinski-Harabasz Score: 165.79638089841595
# Silhouette Score: 0.21146495341823346
#
# Number of clusters: 17
#
# HBDBSCAN-100_5_100 Clustering Evaluation:
# Davies-Bouldin Score: 3.1362164268441877
# Calinski-Harabasz Score: 263.2932472029485
# Silhouette Score: 0.18791071589252506
#
# Number of clusters: 9
#
# HBDBSCAN-100_5_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1856577806152315
# Calinski-Harabasz Score: 730.0875055780183
# Silhouette Score: 0.11385618736262527
#
# Number of clusters: 2
#
# HBDBSCAN-100_5_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-100_20_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.4031978069560647
# Calinski-Harabasz Score: 157.98315439573582
# Silhouette Score: 0.21356035014032537
#
# Number of clusters: 18
#
# HBDBSCAN-100_20_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.955149825509025
# Calinski-Harabasz Score: 255.19749536298377
# Silhouette Score: 0.18075848633345326
#
# Number of clusters: 9
#
# HBDBSCAN-100_20_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1845067699494882
# Calinski-Harabasz Score: 730.7169459178813
# Silhouette Score: 0.11387631709994782
#
# Number of clusters: 2
#
# HBDBSCAN-100_20_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-100_50_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.4000852443929777
# Calinski-Harabasz Score: 166.8659547533918
# Silhouette Score: 0.21384876659823834
#
# Number of clusters: 17
#
# HBDBSCAN-100_50_100 Clustering Evaluation:
# Davies-Bouldin Score: 3.036317534805416
# Calinski-Harabasz Score: 252.50429320090032
# Silhouette Score: 0.1804483767947453
#
# Number of clusters: 9
#
# HBDBSCAN-100_50_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1871769498545233
# Calinski-Harabasz Score: 730.3247639379005
# Silhouette Score: 0.11386990510155207
#
# Number of clusters: 2
#
# HBDBSCAN-100_50_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
#
# HBDBSCAN-100_384_50 Clustering Evaluation:
# Davies-Bouldin Score: 2.6700096906205766
# Calinski-Harabasz Score: 156.19365909771994
# Silhouette Score: 0.20994942435089947
#
# Number of clusters: 18
#
# HBDBSCAN-100_384_100 Clustering Evaluation:
# Davies-Bouldin Score: 2.9334514091815853
# Calinski-Harabasz Score: 224.42728573776105
# Silhouette Score: 0.17803054777766447
#
# Number of clusters: 10
#
# HBDBSCAN-100_384_500 Clustering Evaluation:
# Davies-Bouldin Score: 1.1845067699494882
# Calinski-Harabasz Score: 730.7169459178813
# Silhouette Score: 0.11387631709994782
#
# Number of clusters: 2
#
# HBDBSCAN-100_384_1000 Clustering Evaluation:
# Davies-Bouldin Score: Not applicable
# Calinski-Harabasz Score: Not applicable
# Silhouette Score: Not applicable
#
# Number of clusters: 1
